# %%
from keras.models import Model, load_model
from keras.layers import Dense, Dropout, Flatten, Input, BatchNormalization, Conv2D, MaxPool2D
from tensorflow.keras.optimizers import Adam
from keras_preprocessing.image import ImageDataGenerator
from keras.callbacks import Callback, ModelCheckpoint
import matplotlib.pyplot as plt
import pandas as pd


BATCH_SIZE = 20
IMAGE_SIZE = (256,256)


dataframe = pd.read_csv('contest_foodweight/adj_fried_noodles_dataset.csv', delimiter=',', header=0)


#https://keras.io/api/preprocessing/image/
#https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/
datagen = ImageDataGenerator(
            rescale=1./255,
            brightness_range=[0.9,1.1],
            shear_range=1,
            zoom_range=0.05,
            rotation_range=10,
            width_shift_range=0.03,
            height_shift_range=0.03,
            vertical_flip=True,
            horizontal_flip=True)

datagen_noaug = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_dataframe(
    dataframe=dataframe.loc[0:699],
    directory='contest_foodweight/images',
    x_col='filename',
    y_col='norm_veggie',
    shuffle=True,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='other')

validation_generator = datagen_noaug.flow_from_dataframe(
    dataframe=dataframe.loc[700:1299],
    directory='contest_foodweight/images',
    x_col='filename',
    y_col='norm_veggie',
    shuffle=False,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='other')

test_generator = datagen_noaug.flow_from_dataframe(
    dataframe=dataframe.loc[1300:1856],
    directory='contest_foodweight/images',
    x_col='filename',
    y_col='norm_veggie',
    shuffle=False,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='other')

inputIm = Input(shape = (IMAGE_SIZE[0],IMAGE_SIZE[1],3,))
conv1 = Conv2D(64,3,activation='relu')(inputIm)
conv1 = Conv2D(64,3,activation='relu')(conv1)
conv1 = BatchNormalization()(conv1)
pool1 = MaxPool2D()(conv1)
conv2 = Conv2D(128,3,activation='relu')(pool1)
conv2 = Conv2D(128,3,activation='relu')(conv2)
conv2 = BatchNormalization()(conv2)
pool2 = MaxPool2D()(conv2)
conv3 = Conv2D(256,3,activation='relu')(pool2)
conv3 = Conv2D(256,3,activation='relu')(conv3)
conv3 = BatchNormalization()(conv3)
pool3 = MaxPool2D()(conv3)
conv4 = Conv2D(512,3,activation='relu')(pool3)
conv4 = Conv2D(512,3,activation='relu')(conv4)
conv4 = BatchNormalization()(conv4)
pool4 = MaxPool2D()(conv4)
conv5 = Conv2D(1024,3,activation='relu')(pool4)
conv5 = Conv2D(1024,3,activation='relu')(conv5)
conv5 = BatchNormalization()(conv5)
pool5 = MaxPool2D()(conv5)
flat = Flatten()(pool5)
dense1 = Dense(512,activation='sigmoid')(flat)
dense1 = Dropout(0.5)(dense1)
dense1 = Dense(512,activation='sigmoid')(dense1)
dense1 = Dropout(0.5)(dense1)
dense1 = Dense(512,activation='sigmoid')(dense1)
dense1 = Dropout(0.5)(dense1)
predictedW = Dense(1,activation='sigmoid')(dense1)

model = Model(inputs=inputIm, outputs=predictedW)

model.compile(optimizer=Adam(lr = 1e-4), loss='mse', metrics=['mean_absolute_error'])


class PlotLosses(Callback):
    def on_train_begin(self, logs={}):
        self.x = []
        self.losses = []
        self.val_losses = []
        self.fig = plt.figure()
        self.logs = []

    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(logs)
        self.x.append(epoch)
        self.losses.append(logs.get('mean_absolute_error'))
        self.val_losses.append(logs.get('val_mean_absolute_error'))

        plt.clf()
        plt.plot(self.x, self.losses, label='mean_absolute_error')
        plt.plot(self.x, self.val_losses, label='val_mean_absolute_error')
        plt.legend()
        plt.pause(0.01)


checkpoint = ModelCheckpoint('veggie_best.h5', verbose=1, monitor='val_mean_absolute_error',save_best_only=True, mode='min')
plot_losses = PlotLosses()

#Train Model
model.fit_generator(
    train_generator,
    steps_per_epoch= len(train_generator),
    epochs=60,
    validation_data=validation_generator,
    validation_steps= len(validation_generator),
    callbacks=[checkpoint, plot_losses])


#Test Model
model = load_model('veggie_best.h5')
score = model.evaluate_generator(
    test_generator,
    steps=len(test_generator))
print('score (mse, mae):\n',score)

test_generator.reset()
predict = model.predict_generator(
    test_generator,
    steps=len(test_generator),
    workers = 1,
    use_multiprocessing=False)
print('prediction:\n',predict)
# Out:
# Found 700 validated image filenames.
# Found 600 validated image filenames.
# Found 556 validated image filenames.
# Epoch 1/60
# 35/35 [==============================] - 247s 7s/step - loss: 0.0438 - mean_absolute_error: 0.1487 - val_loss: 0.0460 - val_mean_absolute_error: 0.1379
#
# Epoch 00001: val_mean_absolute_error improved from inf to 0.13786, saving model to veggie_best.h5
# Epoch 2/60
# 35/35 [==============================] - 245s 7s/step - loss: 0.0279 - mean_absolute_error: 0.1169 - val_loss: 0.0455 - val_mean_absolute_error: 0.1373
#
# Epoch 00002: val_mean_absolute_error improved from 0.13786 to 0.13727, saving model to veggie_best.h5
# Epoch 3/60
# 35/35 [==============================] - 244s 7s/step - loss: 0.0258 - mean_absolute_error: 0.1130 - val_loss: 0.0497 - val_mean_absolute_error: 0.1418
#
# Epoch 00003: val_mean_absolute_error did not improve from 0.13727
# Epoch 4/60
# 35/35 [==============================] - 247s 7s/step - loss: 0.0227 - mean_absolute_error: 0.1009 - val_loss: 0.0528 - val_mean_absolute_error: 0.1463
#
# Epoch 00004: val_mean_absolute_error did not improve from 0.13727
# Epoch 5/60
# 35/35 [==============================] - 245s 7s/step - loss: 0.0225 - mean_absolute_error: 0.0969 - val_loss: 0.0552 - val_mean_absolute_error: 0.1505
#
# Epoch 00005: val_mean_absolute_error did not improve from 0.13727
# Epoch 6/60
# 35/35 [==============================] - 247s 7s/step - loss: 0.0213 - mean_absolute_error: 0.0966 - val_loss: 0.0540 - val_mean_absolute_error: 0.1484
#
# Epoch 00006: val_mean_absolute_error did not improve from 0.13727
# Epoch 7/60
# 35/35 [==============================] - 246s 7s/step - loss: 0.0184 - mean_absolute_error: 0.0923 - val_loss: 0.0540 - val_mean_absolute_error: 0.1484
#
# Epoch 00007: val_mean_absolute_error did not improve from 0.13727
# Epoch 8/60
# 35/35 [==============================] - 247s 7s/step - loss: 0.0172 - mean_absolute_error: 0.0894 - val_loss: 0.0540 - val_mean_absolute_error: 0.1485
#
# Epoch 00008: val_mean_absolute_error did not improve from 0.13727
# Epoch 9/60
# 35/35 [==============================] - 243s 7s/step - loss: 0.0178 - mean_absolute_error: 0.0901 - val_loss: 0.0514 - val_mean_absolute_error: 0.1446
#
# Epoch 00009: val_mean_absolute_error did not improve from 0.13727
# Epoch 10/60
# 35/35 [==============================] - 243s 7s/step - loss: 0.0166 - mean_absolute_error: 0.0873 - val_loss: 0.0548 - val_mean_absolute_error: 0.1504
#
# Epoch 00010: val_mean_absolute_error did not improve from 0.13727
# Epoch 11/60
# 35/35 [==============================] - 244s 7s/step - loss: 0.0180 - mean_absolute_error: 0.0872 - val_loss: 0.0556 - val_mean_absolute_error: 0.1512
#
# Epoch 00011: val_mean_absolute_error did not improve from 0.13727
# Epoch 12/60
# 35/35 [==============================] - 246s 7s/step - loss: 0.0159 - mean_absolute_error: 0.0853 - val_loss: 0.0540 - val_mean_absolute_error: 0.1493
#
# Epoch 00012: val_mean_absolute_error did not improve from 0.13727
# Epoch 13/60
# 35/35 [==============================] - 247s 7s/step - loss: 0.0167 - mean_absolute_error: 0.0872 - val_loss: 0.0542 - val_mean_absolute_error: 0.1489
#
# Epoch 00013: val_mean_absolute_error did not improve from 0.13727
# Epoch 14/60
# 35/35 [==============================] - 243s 7s/step - loss: 0.0152 - mean_absolute_error: 0.0832 - val_loss: 0.0530 - val_mean_absolute_error: 0.1476
#
# Epoch 00014: val_mean_absolute_error did not improve from 0.13727
# Epoch 15/60
# 35/35 [==============================] - 243s 7s/step - loss: 0.0146 - mean_absolute_error: 0.0814 - val_loss: 0.0463 - val_mean_absolute_error: 0.1373
#
# Epoch 00015: val_mean_absolute_error did not improve from 0.13727
# Epoch 16/60
# 35/35 [==============================] - 240s 7s/step - loss: 0.0149 - mean_absolute_error: 0.0825 - val_loss: 0.0356 - val_mean_absolute_error: 0.1159
#
# Epoch 00016: val_mean_absolute_error improved from 0.13727 to 0.11585, saving model to veggie_best.h5
# Epoch 17/60
# 35/35 [==============================] - 243s 7s/step - loss: 0.0130 - mean_absolute_error: 0.0748 - val_loss: 0.0163 - val_mean_absolute_error: 0.0858
#
# Epoch 00017: val_mean_absolute_error improved from 0.11585 to 0.08577, saving model to veggie_best.h5
# Epoch 18/60
# 35/35 [==============================] - 243s 7s/step - loss: 0.0137 - mean_absolute_error: 0.0798 - val_loss: 0.0172 - val_mean_absolute_error: 0.0910
#
# Epoch 00018: val_mean_absolute_error did not improve from 0.08577
# Epoch 19/60
# 35/35 [==============================] - 245s 7s/step - loss: 0.0132 - mean_absolute_error: 0.0755 - val_loss: 0.0159 - val_mean_absolute_error: 0.0845
#
# Epoch 00019: val_mean_absolute_error improved from 0.08577 to 0.08446, saving model to veggie_best.h5
# Epoch 20/60
# 35/35 [==============================] - 244s 7s/step - loss: 0.0117 - mean_absolute_error: 0.0753 - val_loss: 0.0119 - val_mean_absolute_error: 0.0742
#
# Epoch 00020: val_mean_absolute_error improved from 0.08446 to 0.07416, saving model to veggie_best.h5
# Epoch 21/60
# 35/35 [==============================] - 244s 7s/step - loss: 0.0106 - mean_absolute_error: 0.0705 - val_loss: 0.0061 - val_mean_absolute_error: 0.0531
#
# Epoch 00021: val_mean_absolute_error improved from 0.07416 to 0.05312, saving model to veggie_best.h5
# Epoch 22/60
# 35/35 [==============================] - 244s 7s/step - loss: 0.0130 - mean_absolute_error: 0.0760 - val_loss: 0.0109 - val_mean_absolute_error: 0.0704
#
# Epoch 00022: val_mean_absolute_error did not improve from 0.05312
# Epoch 23/60
# 35/35 [==============================] - 244s 7s/step - loss: 0.0105 - mean_absolute_error: 0.0706 - val_loss: 0.0162 - val_mean_absolute_error: 0.0833
#
# Epoch 00023: val_mean_absolute_error did not improve from 0.05312
# Epoch 24/60
# 35/35 [==============================] - 245s 7s/step - loss: 0.0102 - mean_absolute_error: 0.0704 - val_loss: 0.0139 - val_mean_absolute_error: 0.0761
#
# Epoch 00024: val_mean_absolute_error did not improve from 0.05312
# Epoch 25/60
# 35/35 [==============================] - 248s 7s/step - loss: 0.0130 - mean_absolute_error: 0.0756 - val_loss: 0.0203 - val_mean_absolute_error: 0.1020
#
# Epoch 00025: val_mean_absolute_error did not improve from 0.05312
# Epoch 26/60
# 35/35 [==============================] - 244s 7s/step - loss: 0.0103 - mean_absolute_error: 0.0688 - val_loss: 0.0499 - val_mean_absolute_error: 0.1631
#
# Epoch 00026: val_mean_absolute_error did not improve from 0.05312
# Epoch 27/60
# 35/35 [==============================] - 245s 7s/step - loss: 0.0103 - mean_absolute_error: 0.0698 - val_loss: 0.0050 - val_mean_absolute_error: 0.0482
#
# Epoch 00027: val_mean_absolute_error improved from 0.05312 to 0.04824, saving model to veggie_best.h5
# Epoch 28/60
# 35/35 [==============================] - 245s 7s/step - loss: 0.0109 - mean_absolute_error: 0.0696 - val_loss: 0.0095 - val_mean_absolute_error: 0.0718
#
# Epoch 00028: val_mean_absolute_error did not improve from 0.04824
# Epoch 29/60
# 35/35 [==============================] - 246s 7s/step - loss: 0.0112 - mean_absolute_error: 0.0707 - val_loss: 0.0154 - val_mean_absolute_error: 0.0893
#
# Epoch 00029: val_mean_absolute_error did not improve from 0.04824
# Epoch 30/60
# 35/35 [==============================] - 247s 7s/step - loss: 0.0093 - mean_absolute_error: 0.0649 - val_loss: 0.0203 - val_mean_absolute_error: 0.1020
#
# Epoch 00030: val_mean_absolute_error did not improve from 0.04824
# Epoch 31/60
# 35/35 [==============================] - 247s 7s/step - loss: 0.0111 - mean_absolute_error: 0.0691 - val_loss: 0.0086 - val_mean_absolute_error: 0.0602
#
# Epoch 00031: val_mean_absolute_error did not improve from 0.04824
# Epoch 32/60
# 35/35 [==============================] - 244s 7s/step - loss: 0.0092 - mean_absolute_error: 0.0659 - val_loss: 0.0062 - val_mean_absolute_error: 0.0507
#
# Epoch 00032: val_mean_absolute_error did not improve from 0.04824
# Epoch 33/60
# 35/35 [==============================] - 246s 7s/step - loss: 0.0098 - mean_absolute_error: 0.0661 - val_loss: 0.0067 - val_mean_absolute_error: 0.0510
#
# Epoch 00033: val_mean_absolute_error did not improve from 0.04824
# Epoch 34/60
# 35/35 [==============================] - 246s 7s/step - loss: 0.0087 - mean_absolute_error: 0.0653 - val_loss: 0.0080 - val_mean_absolute_error: 0.0551
#
# Epoch 00034: val_mean_absolute_error did not improve from 0.04824
# Epoch 35/60
# 35/35 [==============================] - 240s 7s/step - loss: 0.0085 - mean_absolute_error: 0.0648 - val_loss: 0.0142 - val_mean_absolute_error: 0.0791
#
# Epoch 00035: val_mean_absolute_error did not improve from 0.04824
# Epoch 36/60
# 35/35 [==============================] - 241s 7s/step - loss: 0.0080 - mean_absolute_error: 0.0608 - val_loss: 0.0086 - val_mean_absolute_error: 0.0572
#
# Epoch 00036: val_mean_absolute_error did not improve from 0.04824
# Epoch 37/60
# 35/35 [==============================] - 241s 7s/step - loss: 0.0084 - mean_absolute_error: 0.0625 - val_loss: 0.0064 - val_mean_absolute_error: 0.0507
#
# Epoch 00037: val_mean_absolute_error did not improve from 0.04824
# Epoch 38/60
# 35/35 [==============================] - 242s 7s/step - loss: 0.0075 - mean_absolute_error: 0.0613 - val_loss: 0.0125 - val_mean_absolute_error: 0.0619
#
# Epoch 00038: val_mean_absolute_error did not improve from 0.04824
# Epoch 39/60
# 35/35 [==============================] - 242s 7s/step - loss: 0.0074 - mean_absolute_error: 0.0599 - val_loss: 0.0040 - val_mean_absolute_error: 0.0421
#
# Epoch 00039: val_mean_absolute_error improved from 0.04824 to 0.04212, saving model to veggie_best.h5
# Epoch 40/60
# 35/35 [==============================] - 242s 7s/step - loss: 0.0081 - mean_absolute_error: 0.0632 - val_loss: 0.0104 - val_mean_absolute_error: 0.0729
#
# Epoch 00040: val_mean_absolute_error did not improve from 0.04212
# Epoch 41/60
# 35/35 [==============================] - 241s 7s/step - loss: 0.0079 - mean_absolute_error: 0.0606 - val_loss: 0.0072 - val_mean_absolute_error: 0.0553
#
# Epoch 00041: val_mean_absolute_error did not improve from 0.04212
# Epoch 42/60
# 35/35 [==============================] - 238s 7s/step - loss: 0.0086 - mean_absolute_error: 0.0623 - val_loss: 0.0122 - val_mean_absolute_error: 0.0795
#
# Epoch 00042: val_mean_absolute_error did not improve from 0.04212
# Epoch 43/60
# 35/35 [==============================] - 240s 7s/step - loss: 0.0091 - mean_absolute_error: 0.0651 - val_loss: 0.0073 - val_mean_absolute_error: 0.0526
#
# Epoch 00043: val_mean_absolute_error did not improve from 0.04212
# Epoch 44/60
# 35/35 [==============================] - 240s 7s/step - loss: 0.0089 - mean_absolute_error: 0.0620 - val_loss: 0.0133 - val_mean_absolute_error: 0.0867
#
# Epoch 00044: val_mean_absolute_error did not improve from 0.04212
# Epoch 45/60
# 35/35 [==============================] - 238s 7s/step - loss: 0.0081 - mean_absolute_error: 0.0619 - val_loss: 0.0090 - val_mean_absolute_error: 0.0663
#
# Epoch 00045: val_mean_absolute_error did not improve from 0.04212
# Epoch 46/60
# 35/35 [==============================] - 239s 7s/step - loss: 0.0060 - mean_absolute_error: 0.0546 - val_loss: 0.0078 - val_mean_absolute_error: 0.0569
#
# Epoch 00046: val_mean_absolute_error did not improve from 0.04212
# Epoch 47/60
# 35/35 [==============================] - 239s 7s/step - loss: 0.0084 - mean_absolute_error: 0.0628 - val_loss: 0.0108 - val_mean_absolute_error: 0.0726
#
# Epoch 00047: val_mean_absolute_error did not improve from 0.04212
# Epoch 48/60
# 35/35 [==============================] - 238s 7s/step - loss: 0.0071 - mean_absolute_error: 0.0576 - val_loss: 0.0048 - val_mean_absolute_error: 0.0454
#
# Epoch 00048: val_mean_absolute_error did not improve from 0.04212
# Epoch 49/60
# 35/35 [==============================] - 239s 7s/step - loss: 0.0073 - mean_absolute_error: 0.0593 - val_loss: 0.0158 - val_mean_absolute_error: 0.0869
#
# Epoch 00049: val_mean_absolute_error did not improve from 0.04212
# Epoch 50/60
# 35/35 [==============================] - 238s 7s/step - loss: 0.0067 - mean_absolute_error: 0.0580 - val_loss: 0.0050 - val_mean_absolute_error: 0.0454
#
# Epoch 00050: val_mean_absolute_error did not improve from 0.04212
# Epoch 51/60
# 35/35 [==============================] - 241s 7s/step - loss: 0.0059 - mean_absolute_error: 0.0537 - val_loss: 0.0056 - val_mean_absolute_error: 0.0535
#
# Epoch 00051: val_mean_absolute_error did not improve from 0.04212
# Epoch 52/60
# 35/35 [==============================] - 239s 7s/step - loss: 0.0058 - mean_absolute_error: 0.0547 - val_loss: 0.0044 - val_mean_absolute_error: 0.0434
#
# Epoch 00052: val_mean_absolute_error did not improve from 0.04212
# Epoch 53/60
# 35/35 [==============================] - 238s 7s/step - loss: 0.0063 - mean_absolute_error: 0.0551 - val_loss: 0.0046 - val_mean_absolute_error: 0.0466
#
# Epoch 00053: val_mean_absolute_error did not improve from 0.04212
# Epoch 54/60
# 35/35 [==============================] - 237s 7s/step - loss: 0.0080 - mean_absolute_error: 0.0584 - val_loss: 0.0084 - val_mean_absolute_error: 0.0544
#
# Epoch 00054: val_mean_absolute_error did not improve from 0.04212
# Epoch 55/60
# 35/35 [==============================] - 236s 7s/step - loss: 0.0078 - mean_absolute_error: 0.0618 - val_loss: 0.0937 - val_mean_absolute_error: 0.2423
#
# Epoch 00055: val_mean_absolute_error did not improve from 0.04212
# Epoch 56/60
# 35/35 [==============================] - 238s 7s/step - loss: 0.0055 - mean_absolute_error: 0.0525 - val_loss: 0.0053 - val_mean_absolute_error: 0.0504
#
# Epoch 00056: val_mean_absolute_error did not improve from 0.04212
# Epoch 57/60
# 35/35 [==============================] - 240s 7s/step - loss: 0.0059 - mean_absolute_error: 0.0547 - val_loss: 0.0087 - val_mean_absolute_error: 0.0652
#
# Epoch 00057: val_mean_absolute_error did not improve from 0.04212
# Epoch 58/60
# 35/35 [==============================] - 240s 7s/step - loss: 0.0053 - mean_absolute_error: 0.0510 - val_loss: 0.0166 - val_mean_absolute_error: 0.0828
#
# Epoch 00058: val_mean_absolute_error did not improve from 0.04212
# Epoch 59/60
# 35/35 [==============================] - 237s 7s/step - loss: 0.0060 - mean_absolute_error: 0.0526 - val_loss: 0.0069 - val_mean_absolute_error: 0.0513
#
# Epoch 00059: val_mean_absolute_error did not improve from 0.04212
# Epoch 60/60
# 35/35 [==============================] - 239s 7s/step - loss: 0.0053 - mean_absolute_error: 0.0517 - val_loss: 0.0050 - val_mean_absolute_error: 0.0504
#
# Epoch 00060: val_mean_absolute_error did not improve from 0.04212
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:2006: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# score (mse, mae):
#  [0.0054909964092075825, 0.047681309282779694]
# /opt/conda/lib/python3.7/site-packages/keras/engine/training.py:2035: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# prediction:
#  [[0.02880648]
#  [0.0348337 ]
#  [0.05851987]
#  [0.20870024]
#  [0.0831424 ]
#  [0.7852824 ]
#  [0.17531624]
#  [0.5449245 ]
#  [0.47655076]
#  [0.07330078]
#  [0.22827679]
#  [0.03950268]
#  [0.06840989]
#  [0.16605985]
#  [0.05396381]
#  [0.14312264]
#  [0.5602071 ]
#  [0.13392922]
#  [0.117475  ]
#  [0.02482533]
#  [0.3796919 ]
#  [0.10222447]
#  [0.05876455]
#  [0.78205043]
#  [0.02820942]
#  [0.09459662]
#  [0.02578813]
#  [0.03224596]
#  [0.38818502]
#  [0.04425937]
#  [0.47305974]
#  [0.26865   ]
#  [0.04644409]
#  [0.02773675]
#  [0.14574298]
#  [0.05259675]
#  [0.03505847]
#  [0.02553126]
#  [0.22734165]
#  [0.34154403]
#  [0.28294158]
#  [0.70911646]
#  [0.02625251]
#  [0.44991258]
#  [0.08115703]
#  [0.02720067]
#  [0.02743876]
#  [0.06950077]
#  [0.03862792]
#  [0.13899511]
#  [0.02801678]
#  [0.3445705 ]
#  [0.15640396]
#  [0.78414774]
#  [0.02680746]
#  [0.05420005]
#  [0.02933174]
#  [0.14648476]
#  [0.5872741 ]
#  [0.02798995]
#  [0.02594641]
#  [0.10891965]
#  [0.13887864]
#  [0.15613416]
#  [0.02828291]
#  [0.02538276]
#  [0.7511313 ]
#  [0.0610162 ]
#  [0.14905086]
#  [0.594283  ]
#  [0.38372204]
#  [0.03480428]
#  [0.05667868]
#  [0.0366663 ]
#  [0.76933056]
#  [0.02589491]
#  [0.28784245]
#  [0.05463791]
#  [0.24968165]
#  [0.02619779]
#  [0.2363176 ]
#  [0.03680024]
#  [0.0245516 ]
#  [0.37086433]
#  [0.03118795]
#  [0.06216076]
#  [0.54739565]
#  [0.04816884]
#  [0.07120654]
#  [0.12102282]
#  [0.02511173]
#  [0.02812624]
#  [0.3199165 ]
#  [0.04231793]
#  [0.22252908]
#  [0.4574362 ]
#  [0.05943975]
#  [0.02546322]
#  [0.17392552]
#  [0.24936295]
#  [0.08896458]
#  [0.322218  ]
#  [0.06814542]
#  [0.03917506]
#  [0.41432396]
#  [0.7847941 ]
#  [0.05686593]
#  [0.031477  ]
#  [0.7857063 ]
#  [0.02981424]
#  [0.05865043]
#  [0.02933133]
#  [0.04299802]
#  [0.05735311]
#  [0.02732122]
#  [0.06886396]
#  [0.06689963]
#  [0.32959646]
#  [0.03343055]
#  [0.40910646]
#  [0.02665997]
#  [0.02529344]
#  [0.53045475]
#  [0.05906364]
#  [0.7355801 ]
#  [0.02574655]
#  [0.04618129]
#  [0.42508918]
#  [0.3111049 ]
#  [0.0443829 ]
#  [0.27072194]
#  [0.03451622]
#  [0.09769619]
#  [0.11462933]
#  [0.05169004]
#  [0.63631123]
#  [0.5051667 ]
#  [0.07627684]
#  [0.1975222 ]
#  [0.15103742]
#  [0.10356301]
#  [0.2512169 ]
#  [0.05772999]
#  [0.02906492]
#  [0.10097528]
#  [0.03175843]
#  [0.02626619]
#  [0.04679281]
#  [0.3323918 ]
#  [0.7596532 ]
#  [0.03206822]
#  [0.44252324]
#  [0.04044667]
#  [0.03164765]
#  [0.03369239]
#  [0.05378377]
#  [0.43043894]
#  [0.5506278 ]
#  [0.02555174]
#  [0.03365824]
#  [0.02906692]
#  [0.03104734]
#  [0.10466707]
#  [0.07154825]
#  [0.02644974]
#  [0.10210347]
#  [0.46022993]
#  [0.39896694]
#  [0.0278163 ]
#  [0.0386118 ]
#  [0.03350192]
#  [0.02708891]
#  [0.02946079]
#  [0.3333032 ]
#  [0.31789434]
#  [0.329914  ]
#  [0.03155234]
#  [0.7767167 ]
#  [0.09546113]
#  [0.08577424]
#  [0.04662341]
#  [0.3202892 ]
#  [0.48503396]
#  [0.02549052]
#  [0.03744179]
#  [0.09458169]
#  [0.29960293]
#  [0.078455  ]
#  [0.05824754]
#  [0.14526358]
#  [0.32523793]
#  [0.05621961]
#  [0.03184128]
#  [0.1466212 ]
#  [0.44742486]
#  [0.10762691]
#  [0.02522388]
#  [0.0303652 ]
#  [0.06214783]
#  [0.02919203]
#  [0.2393569 ]
#  [0.07536954]
#  [0.15153673]
#  [0.02548504]
#  [0.04616058]
#  [0.0371711 ]
#  [0.0495224 ]
#  [0.36152756]
#  [0.09609812]
#  [0.02554145]
#  [0.09198803]
#  [0.02783665]
#  [0.19406268]
#  [0.07803497]
#  [0.04382667]
#  [0.20647693]
#  [0.02759081]
#  [0.29089457]
#  [0.03815213]
#  [0.149158  ]
#  [0.02676353]
#  [0.56689864]
#  [0.07621351]
#  [0.04035282]
#  [0.02962735]
#  [0.02651954]
#  [0.41873693]
#  [0.02758026]
#  [0.02940044]
#  [0.02632114]
#  [0.03263515]
#  [0.23256758]
#  [0.06007275]
#  [0.07346398]
#  [0.02973688]
#  [0.2396436 ]
#  [0.28396112]
#  [0.02707395]
#  [0.0285942 ]
#  [0.03491524]
#  [0.02574506]
#  [0.20844689]
#  [0.03739917]
#  [0.0573259 ]
#  [0.02965942]
#  [0.02777326]
#  [0.02876478]
#  [0.0273352 ]
#  [0.02807504]
#  [0.0261488 ]
#  [0.02943695]
#  [0.08693644]
#  [0.13234678]
#  [0.6024587 ]
#  [0.05233273]
#  [0.04055911]
#  [0.02606073]
#  [0.02705047]
#  [0.11278298]
#  [0.05998138]
#  [0.03547001]
#  [0.02666757]
#  [0.17271566]
#  [0.139352  ]]
