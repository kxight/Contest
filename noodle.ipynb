# %%
from keras.models import Model, load_model
from keras.layers import Dense, Dropout, Flatten, Input, BatchNormalization, Conv2D, MaxPool2D
from tensorflow.keras.optimizers import Adam
from keras_preprocessing.image import ImageDataGenerator
from keras.callbacks import Callback, ModelCheckpoint
import matplotlib.pyplot as plt
import pandas as pd


BATCH_SIZE = 20
IMAGE_SIZE = (256,256)


dataframe = pd.read_csv('contest_foodweight/adj_fried_noodles_dataset.csv', delimiter=',', header=0)


#https://keras.io/api/preprocessing/image/
#https://machinelearningmastery.com/how-to-configure-image-data-augmentation-when-training-deep-learning-neural-networks/
datagen = ImageDataGenerator(
            rescale=1./255,
            brightness_range=[0.9,1.1],
            shear_range=1,
            zoom_range=0.05,
            rotation_range=10,
            width_shift_range=0.03,
            height_shift_range=0.03,
            vertical_flip=True,
            horizontal_flip=True)

datagen_noaug = ImageDataGenerator(rescale=1./255)

train_generator = datagen.flow_from_dataframe(
    dataframe=dataframe.loc[0:699],
    directory='contest_foodweight/images',
    x_col='filename',
    y_col='norm_noodle',
    shuffle=True,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='other')

validation_generator = datagen_noaug.flow_from_dataframe(
    dataframe=dataframe.loc[700:1279],
    directory='contest_foodweight/images',
    x_col='filename',
    y_col='norm_noodle',
    shuffle=False,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='other')

test_generator = datagen_noaug.flow_from_dataframe(
    dataframe=dataframe.loc[1280:1856],
    directory='contest_foodweight/images',
    x_col='filename',
    y_col='norm_noodle',
    shuffle=False,
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='other')

inputIm = Input(shape = (IMAGE_SIZE[0],IMAGE_SIZE[1],3,))
conv1 = Conv2D(64,3,activation='relu')(inputIm)
conv1 = Conv2D(64,3,activation='relu')(conv1)
conv1 = BatchNormalization()(conv1)
pool1 = MaxPool2D()(conv1)
conv2 = Conv2D(128,3,activation='relu')(pool1)
conv2 = Conv2D(128,3,activation='relu')(conv2)
conv2 = BatchNormalization()(conv2)
pool2 = MaxPool2D()(conv2)
conv3 = Conv2D(256,3,activation='relu')(pool2)
conv3 = Conv2D(256,3,activation='relu')(conv3)
conv3 = BatchNormalization()(conv3)
pool3 = MaxPool2D()(conv3)
conv4 = Conv2D(512,3,activation='relu')(pool3)
conv4 = Conv2D(512,3,activation='relu')(conv4)
conv4 = BatchNormalization()(conv4)
pool4 = MaxPool2D()(conv4)
conv5 = Conv2D(1024,3,activation='relu')(pool4)
conv5 = Conv2D(1024,3,activation='relu')(conv5)
conv5 = BatchNormalization()(conv5)
pool5 = MaxPool2D()(conv5)
flat = Flatten()(pool5)
dense1 = Dense(512,activation='sigmoid')(flat)
dense1 = Dropout(0.5)(dense1)
dense1 = Dense(512,activation='sigmoid')(dense1)
dense1 = Dropout(0.5)(dense1)
dense1 = Dense(512,activation='sigmoid')(dense1)
dense1 = Dropout(0.5)(dense1)
predictedW = Dense(1,activation='sigmoid')(dense1)

model = Model(inputs=inputIm, outputs=predictedW)

model.compile(optimizer=Adam(lr = 1e-4), loss='mse', metrics=['mean_absolute_error'])


class PlotLosses(Callback):
    def on_train_begin(self, logs={}):
        self.x = []
        self.losses = []
        self.val_losses = []
        self.fig = plt.figure()
        self.logs = []

    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(logs)
        self.x.append(epoch)
        self.losses.append(logs.get('mean_absolute_error'))
        self.val_losses.append(logs.get('val_mean_absolute_error'))

        plt.clf()
        plt.plot(self.x, self.losses, label='mean_absolute_error')
        plt.plot(self.x, self.val_losses, label='val_mean_absolute_error')
        plt.legend()
        plt.pause(0.01)


checkpoint = ModelCheckpoint('noodle_best.h5', verbose=1, monitor='val_mean_absolute_error',save_best_only=True, mode='min')
plot_losses = PlotLosses()

#Train Model
model.fit_generator(
    train_generator,
    steps_per_epoch= len(train_generator),
    epochs=60,
    validation_data=validation_generator,
    validation_steps= len(validation_generator),
    callbacks=[checkpoint, plot_losses])


#Test Model
model = load_model('noodle_best.h5')
score = model.evaluate_generator(
    test_generator,
    steps=len(test_generator))
print('score (mse, mae):\n',score)

test_generator.reset()
predict = model.predict_generator(
    test_generator,
    steps=len(test_generator),
    workers = 1,
    use_multiprocessing=False)
print('prediction:\n',predict)
# Out:
# Found 700 validated image filenames.
# Found 580 validated image filenames.
# Found 576 validated image filenames.
# Epoch 1/60
# 35/35 [==============================] - 247s 7s/step - loss: 0.0561 - mean_absolute_error: 0.1766 - val_loss: 0.0712 - val_mean_absolute_error: 0.1851
#
# Epoch 00001: val_mean_absolute_error improved from inf to 0.18512, saving model to noodle_best.h5
# Epoch 2/60
# 35/35 [==============================] - 242s 7s/step - loss: 0.0353 - mean_absolute_error: 0.1354 - val_loss: 0.0765 - val_mean_absolute_error: 0.1913
#
# Epoch 00002: val_mean_absolute_error did not improve from 0.18512
# Epoch 3/60
# 35/35 [==============================] - 240s 7s/step - loss: 0.0275 - mean_absolute_error: 0.1212 - val_loss: 0.0851 - val_mean_absolute_error: 0.2015
#
# Epoch 00003: val_mean_absolute_error did not improve from 0.18512
# Epoch 4/60
# 35/35 [==============================] - 239s 7s/step - loss: 0.0268 - mean_absolute_error: 0.1153 - val_loss: 0.0838 - val_mean_absolute_error: 0.1998
#
# Epoch 00004: val_mean_absolute_error did not improve from 0.18512
# Epoch 5/60
# 35/35 [==============================] - 235s 7s/step - loss: 0.0231 - mean_absolute_error: 0.1085 - val_loss: 0.0876 - val_mean_absolute_error: 0.2048
#
# Epoch 00005: val_mean_absolute_error did not improve from 0.18512
# Epoch 6/60
# 35/35 [==============================] - 238s 7s/step - loss: 0.0244 - mean_absolute_error: 0.1052 - val_loss: 0.0885 - val_mean_absolute_error: 0.2060
#
# Epoch 00006: val_mean_absolute_error did not improve from 0.18512
# Epoch 7/60
# 35/35 [==============================] - 240s 7s/step - loss: 0.0199 - mean_absolute_error: 0.1014 - val_loss: 0.0871 - val_mean_absolute_error: 0.2041
#
# Epoch 00007: val_mean_absolute_error did not improve from 0.18512
# Epoch 8/60
# 35/35 [==============================] - 239s 7s/step - loss: 0.0203 - mean_absolute_error: 0.1029 - val_loss: 0.0870 - val_mean_absolute_error: 0.2039
#
# Epoch 00008: val_mean_absolute_error did not improve from 0.18512
# Epoch 9/60
# 35/35 [==============================] - 237s 7s/step - loss: 0.0192 - mean_absolute_error: 0.0987 - val_loss: 0.0853 - val_mean_absolute_error: 0.2018
#
# Epoch 00009: val_mean_absolute_error did not improve from 0.18512
# Epoch 10/60
# 35/35 [==============================] - 241s 7s/step - loss: 0.0185 - mean_absolute_error: 0.0971 - val_loss: 0.0881 - val_mean_absolute_error: 0.2058
#
# Epoch 00010: val_mean_absolute_error did not improve from 0.18512
# Epoch 11/60
# 35/35 [==============================] - 244s 7s/step - loss: 0.0216 - mean_absolute_error: 0.1036 - val_loss: 0.0703 - val_mean_absolute_error: 0.1867
#
# Epoch 00011: val_mean_absolute_error did not improve from 0.18512
# Epoch 12/60
# 35/35 [==============================] - 243s 7s/step - loss: 0.0190 - mean_absolute_error: 0.0972 - val_loss: 0.0880 - val_mean_absolute_error: 0.2057
#
# Epoch 00012: val_mean_absolute_error did not improve from 0.18512
# Epoch 13/60
# 35/35 [==============================] - 246s 7s/step - loss: 0.0170 - mean_absolute_error: 0.0914 - val_loss: 0.0516 - val_mean_absolute_error: 0.1574
#
# Epoch 00013: val_mean_absolute_error improved from 0.18512 to 0.15738, saving model to noodle_best.h5
# Epoch 14/60
# 35/35 [==============================] - 245s 7s/step - loss: 0.0165 - mean_absolute_error: 0.0927 - val_loss: 0.0761 - val_mean_absolute_error: 0.1942
#
# Epoch 00014: val_mean_absolute_error did not improve from 0.15738
# Epoch 15/60
# 35/35 [==============================] - 244s 7s/step - loss: 0.0162 - mean_absolute_error: 0.0886 - val_loss: 0.0802 - val_mean_absolute_error: 0.1981
#
# Epoch 00015: val_mean_absolute_error did not improve from 0.15738
# Epoch 16/60
# 35/35 [==============================] - 241s 7s/step - loss: 0.0197 - mean_absolute_error: 0.0997 - val_loss: 0.0210 - val_mean_absolute_error: 0.1044
#
# Epoch 00016: val_mean_absolute_error improved from 0.15738 to 0.10440, saving model to noodle_best.h5
# Epoch 17/60
# 35/35 [==============================] - 242s 7s/step - loss: 0.0172 - mean_absolute_error: 0.0927 - val_loss: 0.0146 - val_mean_absolute_error: 0.0883
#
# Epoch 00017: val_mean_absolute_error improved from 0.10440 to 0.08832, saving model to noodle_best.h5
# Epoch 18/60
# 35/35 [==============================] - 245s 7s/step - loss: 0.0149 - mean_absolute_error: 0.0860 - val_loss: 0.0272 - val_mean_absolute_error: 0.1161
#
# Epoch 00018: val_mean_absolute_error did not improve from 0.08832
# Epoch 19/60
# 35/35 [==============================] - 246s 7s/step - loss: 0.0145 - mean_absolute_error: 0.0844 - val_loss: 0.0096 - val_mean_absolute_error: 0.0664
#
# Epoch 00019: val_mean_absolute_error improved from 0.08832 to 0.06638, saving model to noodle_best.h5
# Epoch 20/60
# 35/35 [==============================] - 241s 7s/step - loss: 0.0151 - mean_absolute_error: 0.0877 - val_loss: 0.0158 - val_mean_absolute_error: 0.0880
#
# Epoch 00020: val_mean_absolute_error did not improve from 0.06638
# Epoch 21/60
# 35/35 [==============================] - 243s 7s/step - loss: 0.0160 - mean_absolute_error: 0.0884 - val_loss: 0.0137 - val_mean_absolute_error: 0.0803
#
# Epoch 00021: val_mean_absolute_error did not improve from 0.06638
# Epoch 22/60
# 35/35 [==============================] - 241s 7s/step - loss: 0.0160 - mean_absolute_error: 0.0904 - val_loss: 0.0066 - val_mean_absolute_error: 0.0568
#
# Epoch 00022: val_mean_absolute_error improved from 0.06638 to 0.05680, saving model to noodle_best.h5
# Epoch 23/60
# 35/35 [==============================] - 245s 7s/step - loss: 0.0137 - mean_absolute_error: 0.0820 - val_loss: 0.0082 - val_mean_absolute_error: 0.0620
#
# Epoch 00023: val_mean_absolute_error did not improve from 0.05680
# Epoch 24/60
# 35/35 [==============================] - 244s 7s/step - loss: 0.0131 - mean_absolute_error: 0.0817 - val_loss: 0.0096 - val_mean_absolute_error: 0.0662
#
# Epoch 00024: val_mean_absolute_error did not improve from 0.05680
# Epoch 25/60
# 35/35 [==============================] - 257s 7s/step - loss: 0.0140 - mean_absolute_error: 0.0840 - val_loss: 0.0070 - val_mean_absolute_error: 0.0587
#
# Epoch 00025: val_mean_absolute_error did not improve from 0.05680
# Epoch 26/60
# 35/35 [==============================] - 257s 7s/step - loss: 0.0139 - mean_absolute_error: 0.0816 - val_loss: 0.0098 - val_mean_absolute_error: 0.0678
#
# Epoch 00026: val_mean_absolute_error did not improve from 0.05680
# Epoch 27/60
# 35/35 [==============================] - 255s 7s/step - loss: 0.0121 - mean_absolute_error: 0.0779 - val_loss: 0.0097 - val_mean_absolute_error: 0.0726
#
# Epoch 00027: val_mean_absolute_error did not improve from 0.05680
# Epoch 28/60
# 35/35 [==============================] - 258s 7s/step - loss: 0.0127 - mean_absolute_error: 0.0803 - val_loss: 0.0236 - val_mean_absolute_error: 0.1153
#
# Epoch 00028: val_mean_absolute_error did not improve from 0.05680
# Epoch 29/60
# 35/35 [==============================] - 257s 7s/step - loss: 0.0132 - mean_absolute_error: 0.0811 - val_loss: 0.0560 - val_mean_absolute_error: 0.1574
#
# Epoch 00029: val_mean_absolute_error did not improve from 0.05680
# Epoch 30/60
# 35/35 [==============================] - 256s 7s/step - loss: 0.0123 - mean_absolute_error: 0.0767 - val_loss: 0.0368 - val_mean_absolute_error: 0.1413
#
# Epoch 00030: val_mean_absolute_error did not improve from 0.05680
# Epoch 31/60
# 35/35 [==============================] - 258s 7s/step - loss: 0.0096 - mean_absolute_error: 0.0709 - val_loss: 0.0196 - val_mean_absolute_error: 0.0940
#
# Epoch 00031: val_mean_absolute_error did not improve from 0.05680
# Epoch 32/60
# 35/35 [==============================] - 256s 7s/step - loss: 0.0135 - mean_absolute_error: 0.0811 - val_loss: 0.0203 - val_mean_absolute_error: 0.1060
#
# Epoch 00032: val_mean_absolute_error did not improve from 0.05680
# Epoch 33/60
# 35/35 [==============================] - 253s 7s/step - loss: 0.0132 - mean_absolute_error: 0.0827 - val_loss: 0.0055 - val_mean_absolute_error: 0.0529
#
# Epoch 00033: val_mean_absolute_error improved from 0.05680 to 0.05293, saving model to noodle_best.h5
# Epoch 34/60
# 35/35 [==============================] - 253s 7s/step - loss: 0.0098 - mean_absolute_error: 0.0708 - val_loss: 0.0066 - val_mean_absolute_error: 0.0569
#
# Epoch 00034: val_mean_absolute_error did not improve from 0.05293
# Epoch 35/60
# 35/35 [==============================] - 254s 7s/step - loss: 0.0104 - mean_absolute_error: 0.0735 - val_loss: 0.0149 - val_mean_absolute_error: 0.0792
#
# Epoch 00035: val_mean_absolute_error did not improve from 0.05293
# Epoch 36/60
# 35/35 [==============================] - 256s 7s/step - loss: 0.0098 - mean_absolute_error: 0.0706 - val_loss: 0.0061 - val_mean_absolute_error: 0.0577
#
# Epoch 00036: val_mean_absolute_error did not improve from 0.05293
# Epoch 37/60
# 35/35 [==============================] - 257s 7s/step - loss: 0.0090 - mean_absolute_error: 0.0678 - val_loss: 0.0093 - val_mean_absolute_error: 0.0668
#
# Epoch 00037: val_mean_absolute_error did not improve from 0.05293
# Epoch 38/60
# 35/35 [==============================] - 256s 7s/step - loss: 0.0099 - mean_absolute_error: 0.0714 - val_loss: 0.0093 - val_mean_absolute_error: 0.0618
#
# Epoch 00038: val_mean_absolute_error did not improve from 0.05293
# Epoch 39/60
# 35/35 [==============================] - 255s 7s/step - loss: 0.0095 - mean_absolute_error: 0.0716 - val_loss: 0.0148 - val_mean_absolute_error: 0.0905
#
# Epoch 00039: val_mean_absolute_error did not improve from 0.05293
# Epoch 40/60
# 35/35 [==============================] - 257s 7s/step - loss: 0.0090 - mean_absolute_error: 0.0679 - val_loss: 0.0073 - val_mean_absolute_error: 0.0581
#
# Epoch 00040: val_mean_absolute_error did not improve from 0.05293
# Epoch 41/60
# 35/35 [==============================] - 258s 7s/step - loss: 0.0091 - mean_absolute_error: 0.0695 - val_loss: 0.0061 - val_mean_absolute_error: 0.0550
#
# Epoch 00041: val_mean_absolute_error did not improve from 0.05293
# Epoch 42/60
# 35/35 [==============================] - 259s 7s/step - loss: 0.0079 - mean_absolute_error: 0.0645 - val_loss: 0.0064 - val_mean_absolute_error: 0.0572
#
# Epoch 00042: val_mean_absolute_error did not improve from 0.05293
# Epoch 43/60
# 35/35 [==============================] - 257s 7s/step - loss: 0.0088 - mean_absolute_error: 0.0687 - val_loss: 0.0143 - val_mean_absolute_error: 0.0887
#
# Epoch 00043: val_mean_absolute_error did not improve from 0.05293
# Epoch 44/60
# 35/35 [==============================] - 255s 7s/step - loss: 0.0075 - mean_absolute_error: 0.0621 - val_loss: 0.0067 - val_mean_absolute_error: 0.0616
#
# Epoch 00044: val_mean_absolute_error did not improve from 0.05293
# Epoch 45/60
# 35/35 [==============================] - 256s 7s/step - loss: 0.0086 - mean_absolute_error: 0.0661 - val_loss: 0.0142 - val_mean_absolute_error: 0.0848
#
# Epoch 00045: val_mean_absolute_error did not improve from 0.05293
# Epoch 46/60
# 35/35 [==============================] - 257s 7s/step - loss: 0.0086 - mean_absolute_error: 0.0650 - val_loss: 0.0085 - val_mean_absolute_error: 0.0648
#
# Epoch 00046: val_mean_absolute_error did not improve from 0.05293
# Epoch 47/60
# 35/35 [==============================] - 255s 7s/step - loss: 0.0089 - mean_absolute_error: 0.0667 - val_loss: 0.0319 - val_mean_absolute_error: 0.1101
#
# Epoch 00047: val_mean_absolute_error did not improve from 0.05293
# Epoch 48/60
# 35/35 [==============================] - 258s 7s/step - loss: 0.0080 - mean_absolute_error: 0.0651 - val_loss: 0.0159 - val_mean_absolute_error: 0.0878
#
# Epoch 00048: val_mean_absolute_error did not improve from 0.05293
# Epoch 49/60
# 35/35 [==============================] - 256s 7s/step - loss: 0.0077 - mean_absolute_error: 0.0635 - val_loss: 0.0069 - val_mean_absolute_error: 0.0598
#
# Epoch 00049: val_mean_absolute_error did not improve from 0.05293
# Epoch 50/60
# 35/35 [==============================] - 254s 7s/step - loss: 0.0075 - mean_absolute_error: 0.0638 - val_loss: 0.0125 - val_mean_absolute_error: 0.0796
#
# Epoch 00050: val_mean_absolute_error did not improve from 0.05293
# Epoch 51/60
# 35/35 [==============================] - 257s 7s/step - loss: 0.0078 - mean_absolute_error: 0.0639 - val_loss: 0.0234 - val_mean_absolute_error: 0.0954
#
# Epoch 00051: val_mean_absolute_error did not improve from 0.05293
# Epoch 52/60
# 35/35 [==============================] - 258s 7s/step - loss: 0.0075 - mean_absolute_error: 0.0628 - val_loss: 0.0156 - val_mean_absolute_error: 0.0871
#
# Epoch 00052: val_mean_absolute_error did not improve from 0.05293
# Epoch 53/60
# 35/35 [==============================] - 257s 7s/step - loss: 0.0077 - mean_absolute_error: 0.0636 - val_loss: 0.0059 - val_mean_absolute_error: 0.0548
#
# Epoch 00053: val_mean_absolute_error did not improve from 0.05293
# Epoch 54/60
# 35/35 [==============================] - 257s 7s/step - loss: 0.0065 - mean_absolute_error: 0.0593 - val_loss: 0.0072 - val_mean_absolute_error: 0.0587
#
# Epoch 00054: val_mean_absolute_error did not improve from 0.05293
# Epoch 55/60
# 35/35 [==============================] - 258s 7s/step - loss: 0.0066 - mean_absolute_error: 0.0586 - val_loss: 0.0041 - val_mean_absolute_error: 0.0461
#
# Epoch 00055: val_mean_absolute_error improved from 0.05293 to 0.04608, saving model to noodle_best.h5
# Epoch 56/60
# 35/35 [==============================] - 257s 7s/step - loss: 0.0069 - mean_absolute_error: 0.0606 - val_loss: 0.0066 - val_mean_absolute_error: 0.0577
#
# Epoch 00056: val_mean_absolute_error did not improve from 0.04608
# Epoch 57/60
# 35/35 [==============================] - 259s 7s/step - loss: 0.0070 - mean_absolute_error: 0.0612 - val_loss: 0.0051 - val_mean_absolute_error: 0.0509
#
# Epoch 00057: val_mean_absolute_error did not improve from 0.04608
# Epoch 58/60
# 35/35 [==============================] - 258s 7s/step - loss: 0.0061 - mean_absolute_error: 0.0572 - val_loss: 0.0043 - val_mean_absolute_error: 0.0479
#
# Epoch 00058: val_mean_absolute_error did not improve from 0.04608
# Epoch 59/60
# 35/35 [==============================] - 260s 7s/step - loss: 0.0055 - mean_absolute_error: 0.0551 - val_loss: 0.0042 - val_mean_absolute_error: 0.0471
#
# Epoch 00059: val_mean_absolute_error did not improve from 0.04608
# Epoch 60/60
# 28/35 [=======================>......] - ETA: 44s - loss: 0.0060 - mean_absolute_error: 0.0567
